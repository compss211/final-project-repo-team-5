# %%
import pandas as pd

df = pd.read_csv('/Users/isabellalatchamradusky/Documents/GitHub/final-project-repo-team-5/data/Chatgpt_Tweets_Nov30_Feb11.csv', encoding='latin1') 

pd.set_option('display.max_colwidth', None)
df.head(5)
# Out:
# /var/folders/fg/6k8xxqb977767kb6c_mvqd8c0000gn/T/ipykernel_56426/81055249.py:3: DtypeWarning: Columns (2,3,4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/isabellalatchamradusky/Documents/GitHub/final-project-repo-team-5/data/Chatgpt_Tweets_Nov30_Feb11.csv', encoding='latin1')
#                                                                                                                                                                                                                                                     Text  \
# 0  If I were a journalist or reporter writing click-bait for a living then I'd be worried: BuzzFeed Inc. said it would rely on ChatGPT creator OpenAI to enhance its quizzes and personalize some content for audiences https://t.co/E8Ev0tXIEr via @WSJ
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975452 entries, 0 to 975451
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Text       975452 non-null  object
#  1   date       975452 non-null  object
#  2   retweets   975452 non-null  object
#  3   replies    975452 non-null  object
#  4   likes      975452 non-null  object
#  5   location   705267 non-null  object
#  6   followers  975452 non-null  object
#  7   following  975452 non-null  object
# dtypes: object(8)
# memory usage: 59.5+ MB

# %%
df.isnull()
# Out:
#          Text   date  retweets  replies  likes  location  followers  following
# 0       False  False     False    False  False     False      False      False
# 1       False  False     False    False  False     False      False      False
# 2       False  False     False    False  False      True      False      False
# 3       False  False     False    False  False      True      False      False
# 4       False  False     False    False  False     False      False      False
# ...       ...    ...       ...      ...    ...       ...        ...        ...
# 975447  False  False     False    False  False      True      False      False
# 975448  False  False     False    False  False     False      False      False
# 975449  False  False     False    False  False     False      False      False
# 975450  False  False     False    False  False      True      False      False
# 975451  False  False     False    False  False     False      False      False
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert relevant columns to numeric
numeric_cols = ['retweets', 'replies', 'likes', 'followers', 'following']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

df[numeric_cols].hist(figsize=(10, 8), bins=30)
plt.tight_layout()
plt.show()

sns.pairplot(df[numeric_cols].dropna())
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1041457f0>>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
